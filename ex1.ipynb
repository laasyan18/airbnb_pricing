# %%
import pandas as pd
df =pd.read_excel("C:/Users/laasy/Downloads/Telegram Desktop/Sample - EU Superstore.xls")
print(df.head())
# Out:
#    Row ID         Order ID Order Date Dispatch Date   Delivery Mode  \
# 0       1  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 1       2  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 2       3  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 3       4  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
# 4       5  ES-2024-1311038 2024-02-07    2024-02-11  Standard Class
#
#   Customer ID   Customer Name    Segment   City State/Province  \
# 0    AS-10045  Aaron Smayling  Corporate  Leeds        England
# 1    AS-10045  Aaron Smayling  Corporate  Leeds        England
# 2    AS-10045  Aaron Smayling  Corporate  Leeds        England
# 3    AS-10045  Aaron Smayling  Corporate  Leeds        England
# 4    AS-10045  Aaron Smayling  Corporate  Leeds        England
#
#    Country/Region Region       Product ID         Category Sub-Category  \
# 0  United Kingdom  North  OFF-ST-10000988  Office Supplies      Storage
# ...

# %%
print(df.tail())
# Out:
#       Row ID         Order ID Order Date Dispatch Date   Delivery Mode  \
# 9995    9996  ES-2021-3780358 2021-11-16    2021-11-19     First Class
# 9996    9997  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
# 9997    9998  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
# 9998    9999  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
# 9999   10000  ES-2022-5371207 2022-01-25    2022-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City State/Province  \
# 9995    CC-12100    Chad Cunningham  Home Office   Rovigo         Veneto
# 9996    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
# 9997    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
# 9998    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
# 9999    GB-14575  Giulietta Baptist     Consumer  Hamburg        Hamburg
#
#      Country/Region   Region       Product ID         Category Sub-Category  \
# ...
